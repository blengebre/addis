# %%
def clean(text):

    try:
        df = pd.read_excel(text, engine="openpyxl")
    except Exception as e:
        print("❌ File read error:", e)
        return None

    df.columns = ['Amharic', 'Oromo']

    df = df.dropna(subset=['Amharic', 'Oromo'])
    df = df.drop_duplicates(subset=['Amharic', 'Oromo'])

    for col in df.columns:
        df[col] = df[col].astype(str).str.strip()

    def remove_noise(text):
        text = str(text)
        return re.sub(r'[\x00-\x1f\x7f]', '', text)

    df['Amharic'] = df['Amharic'].apply(remove_noise)
    df['Oromo'] = df['Oromo'].apply(remove_noise)

    def normalize_amharic(text):
        text = str(text)
        wordamh = {
            "ሐ": "ሀ", "ኀ": "ሀ", "ሠ": "ሰ", "ኣ": "አ",
            "ዐ": "አ", "ዓ": "አ", "ፀ": "ጸ", "ሏ": "ሉዋ",
            "ሟ": "ሙዋ", "ሧ": "ሱዋ", "ሷ": "ሱዋ", "ሿ": "ሹዋ",
            "ቋ": "ቁዋ", "ቧ": "ቡዋ", "ቷ": "ቱዋ", "ቿ": "ቹዋ",
            "ኋ": "ኹዋ"
        }
        for k, v in wordamh.items():
            text = text.replace(k, v)
        return text
    df['Amharic'] = df['Amharic'].apply(normalize_amharic)

    def normalize_text_lower(text):
        text = str(text).lower().strip()
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'([.!?,;:])\1+', r'\1', text)
        return text

    df['Oromo'] = df['Oromo'].apply(normalize_text_lower)

    df.to_excel("cleaned_amh_omo.xlsx", index=False)

    return df

# %%
pip install tensorflow[and-cuda]

# %%
pip install nltk

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sentencepiece as spm

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Input,
    Embedding,
    Dense,
    Dropout,
    LayerNormalization,
    MultiHeadAttention
)
from tensorflow.keras.models import Model

# =====================================================
# LOAD DATA
# =====================================================

df = pd.read_excel("cleaned_amh_omo.xlsx")



train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42
)

# =====================================================
# SAVE TEXT FILES FOR SENTENCEPIECE
# =====================================================

with open("amharic.txt", "w", encoding="utf-8") as f:
    for s in train_df["Amharic"]:
        f.write(s + "\n")

with open("oromo.txt", "w", encoding="utf-8") as f:
    for s in train_df["Oromo"]:
        f.write(s + "\n")

# =====================================================
# TRAIN SENTENCEPIECE TOKENIZERS
# =====================================================

spm.SentencePieceTrainer.train(
    input="amharic.txt",
    model_prefix="am",
    vocab_size=4000,
    model_type="bpe",
    pad_id=0,
    unk_id=1,
    bos_id=2,
    eos_id=3
)

spm.SentencePieceTrainer.train(
    input="oromo.txt",
    model_prefix="om",
    vocab_size=4000,
    model_type="bpe",
    pad_id=0,
    unk_id=1,
    bos_id=2,
    eos_id=3
)

# =====================================================
# VOCAB SIZE (MISSING PART)
# =====================================================


# =====================================================
# LOAD TOKENIZERS
# =====================================================

am_sp = spm.SentencePieceProcessor()
am_sp.load("am.model")

om_sp = spm.SentencePieceProcessor()
om_sp.load("om.model")

am_vocab_size = am_sp.get_piece_size()
om_vocab_size = om_sp.get_piece_size()

d_model = 128
num_heads = 4
ff_dim = 512
# =====================================================
# TOKENIZATION
# =====================================================

X_train = [
    am_sp.encode(s, out_type=int)
    for s in train_df["Amharic"]
]

y_train = [
    om_sp.encode(s, out_type=int)
    for s in train_df["Oromo"]
]

X_val = [
    am_sp.encode(s, out_type=int)
    for s in val_df["Amharic"]
]

y_val = [
    om_sp.encode(s, out_type=int)
    for s in val_df["Oromo"]
]

# =====================================================
# PADDING
# =====================================================

max_in = max(len(x) for x in X_train)
max_out = max(len(y) for y in y_train)

X_train = pad_sequences(X_train, maxlen=max_in, padding="post")
X_val   = pad_sequences(X_val, maxlen=max_in, padding="post")

y_train = pad_sequences(y_train, maxlen=max_out, padding="post")
y_val   = pad_sequences(y_val, maxlen=max_out, padding="post")

# Decoder inputs and targets
decoder_input_train = y_train[:, :-1]
decoder_target_train = y_train[:, 1:]

decoder_input_val = y_val[:, :-1]
decoder_target_val = y_val[:, 1:]

# =====================================================
# POSITIONAL ENCODING
# =====================================================

def positional_encoding(max_len, d_model):

    pos = np.arange(max_len)[:, np.newaxis]
    i = np.arange(d_model)[np.newaxis, :]

    angle_rates = 1 / np.power(
        10000,
        (2 * (i // 2)) / np.float32(d_model)
    )

    angle_rads = pos * angle_rates

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    return tf.cast(
        angle_rads[np.newaxis, ...],
        dtype=tf.float32
    )

# =====================================================
# TRANSFORMER BLOCK
# =====================================================

def transformer_block(x, num_heads, d_model, ff_dim, dropout=0.1):

    attn = MultiHeadAttention(
        num_heads=num_heads,
        key_dim=d_model // num_heads
    )(x, x)

    x = LayerNormalization(epsilon=1e-6)(x + Dropout(dropout)(attn))

    ffn = Dense(ff_dim, activation="relu")(x)
    ffn = Dense(d_model)(ffn)

    x = LayerNormalization(epsilon=1e-6)(x + Dropout(dropout)(ffn))

    return x
#
# =====================================================
def encoder(x, num_layers=2):
    for _ in range(num_layers):
        x = transformer_block(x, num_heads, d_model, ff_dim)
    return x
def decoder_block(x, enc_output):

    # masked self attention
    attn1 = MultiHeadAttention(
        num_heads=num_heads,
        key_dim=d_model // num_heads,
        use_causal_mask=True
    )(x, x)

    x = LayerNormalization(epsilon=1e-6)(x + attn1)

    # cross attention
    attn2 = MultiHeadAttention(
        num_heads=num_heads,
        key_dim=d_model // num_heads
    )(x, enc_output)

    x = LayerNormalization(epsilon=1e-6)(x + attn2)

    # feed forward
    ffn = Dense(ff_dim, activation="relu")(x)
    ffn = Dense(d_model)(ffn)

    x = LayerNormalization(epsilon=1e-6)(x + ffn)

    return x
# Encoder
encoder_inputs = Input(shape=(max_in,))
enc_embed = Embedding(am_vocab_size, d_model)(encoder_inputs)
enc_embed += positional_encoding(max_in, d_model)

enc_output = encoder(enc_embed, num_layers=2)

# Decoder
decoder_inputs = Input(shape=(max_out-1,))
dec_embed = Embedding(om_vocab_size, d_model)(decoder_inputs)
dec_embed += positional_encoding(max_out-1, d_model)

dec_output = decoder_block(dec_embed, enc_output)

outputs = Dense(om_vocab_size, activation="softmax")(dec_output)

model = Model([encoder_inputs, decoder_inputs], outputs)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)
history = model.fit(
    [X_train, decoder_input_train],
    decoder_target_train,
    validation_data=(
        [X_val, decoder_input_val],
        decoder_target_val
    ),
    batch_size=16,
    epochs=20
)

# =====================================================
# INFERENCE FUNCTION
# =====================================================
# =====================================================
# TRAIN
# =====================================================


model.save("amh_omo_transformer.keras")

print("Model saved successfully!")
# =====================================================
# BLEU EVALUATION
# =====================================================

from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

smooth = SmoothingFunction().method4

def compute_bleu(df, n=100):

    df_sample = df.sample(n)

    scores = []

    for _, row in df_sample.iterrows():
        ref = row["Oromo"].split()
        pred = translate(row["Amharic"]).split()

        scores.append(
            sentence_bleu([ref], pred, smoothing_function=smooth)
        )

    return sum(scores) / len(scores)

print("BLEU:", compute_bleu(test_df))
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: amharic.txt
#   input_format:
#   model_prefix: am
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: amharic.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 115440 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=2438695
# trainer_interface.cc(552) LOG(INFO) Done: 99.9507% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=220
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999507
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 115440 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 115440
# trainer_interface.cc(611) LOG(INFO) Done! 55471
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=58603 min_freq=316
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9996 size=20 all=11750 active=2460 piece=▁ተ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5575 size=40 all=12701 active=3411 piece=▁ላ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3714 size=60 all=13396 active=4106 piece=ችን
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2918 size=80 all=14156 active=4866 piece=ን።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2337 size=100 all=15164 active=5874 piece=▁አለብ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2335 min_freq=290
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1987 size=120 all=15617 active=1448 piece=ኝም።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1632 size=140 all=16275 active=2106 piece=▁ና
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1474 size=160 all=16970 active=2801 piece=▁የእ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1366 size=180 all=17845 active=3676 piece=ረን
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1225 size=200 all=18657 active=4488 piece=ችሁ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1223 min_freq=249
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1146 size=220 all=19274 active=1574 piece=▁ሞ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1041 size=240 all=19824 active=2124 piece=▁ሙ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=950 size=260 all=20328 active=2628 piece=▁አልችልም።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=898 size=280 all=20936 active=3236 piece=▁የበ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=854 size=300 all=21434 active=3734 piece=▁እችላ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=853 min_freq=209
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=784 size=320 all=21908 active=1544 piece=ቁዋ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=741 size=340 all=22503 active=2139 piece=▁ቃ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=696 size=360 all=23049 active=2685 piece=ያው
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=660 size=380 all=23429 active=3065 piece=ቀጥ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=632 size=400 all=24046 active=3682 piece=▁ምክ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=632 min_freq=174
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=606 size=420 all=24466 active=1612 piece=ነው
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq

# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=3380 all=57177 active=3519 piece=ደርግም።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=3400 all=57219 active=3561 piece=በሩ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=54 min_freq=27
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=3420 all=57415 active=3037 piece=▁ሙዚየ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=3440 all=57449 active=3071 piece=▁መከረችው።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=3460 all=57659 active=3281 piece=▁ቀና
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=3480 all=57758 active=3380 piece=▁ደርሶ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=3500 all=57769 active=3391 piece=▁እንደምትፈልግ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=3520 all=58028 active=3148 piece=▁ፕሬ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=3540 all=58091 active=3211 piece=▁ጥንድ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=3560 all=58125 active=3245 piece=▁ያድርጉ።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=3580 all=58182 active=3302 piece=ማማኝ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=3600 all=58354 active=3474 piece=▁የጠፋ
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=51 min_freq=25
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=3620 all=58397 active=2950 piece=▁እንደሚሰራ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=3640 all=58583 active=3136 piece=▁ምት
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=3660 all=58730 active=3283 piece=▁ገንዳ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=3680 all=58749 active=3302 piece=▁የሚለውን
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=3700 all=58865 active=3418 piece=ባል።
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=49 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=3720 all=58953 active=3020 piece=▁ጥልቅ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=3740 all=59002 active=3069 piece=▁ተመለከተ።
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=3760 all=59136 active=3203 piece=ፈጥሮ
# trainer_interface.cc(689) LOG(INFO) Saving model: am.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: am.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: oromo.txt
#   input_format:
#   model_prefix: om
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: oromo.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 115440 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4335006
# trainer_interface.cc(552) LOG(INFO) Done: 99.9565% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=36
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999565
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 115440 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 115440
# trainer_interface.cc(611) LOG(INFO) Done! 28921
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=191679 min_freq=1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29926 size=20 all=1125 active=1088 piece=in
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16301 size=40 all=1912 active=1875 piece=▁y
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10188 size=60 all=2576 active=2539 piece=baa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7289 size=80 all=3269 active=3232 piece=il
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5827 size=100 all=3697 active=3660 piece=▁c
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5774 min_freq=291
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4948 size=120 all=4180 active=1452 piece=taa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4096 size=140 all=4819 active=2091 piece=▁natti
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3369 size=160 all=5236 active=2508 piece=▁deem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2879 size=180 all=5640 active=2912 piece=iq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2496 size=200 all=6241 active=3513 piece=▁gaarii
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2469 min_freq=285
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2249 size=220 all=6555 active=1310 piece=eenya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2031 size=240 all=6909 active=1664 piece=▁deeb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1901 size=260 all=7230 active=1985 piece=▁of
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1721 size=280 all=7530 active=2285 piece=dii
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=3360 all=27033 active=1391 piece=▁dhiphina
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=3380 all=27064 active=1422 piece=▁gamm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=3400 all=27086 active=1444 piece=▁miirri
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=42 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=3420 all=27094 active=1363 piece=▁bitadheera
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=3440 all=27148 active=1417 piece=▁amalli
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=3460 all=27175 active=1444 piece=▁hubachuun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=3480 all=27211 active=1480 piece=▁darbu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=3500 all=27238 active=1507 piece=ibsiifate
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=40 min_freq=23
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=3520 all=27269 active=1393 piece=▁yuu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=3540 all=27318 active=1442 piece=▁furuuf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=3560 all=27321 active=1445 piece=▁waamicha
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=3580 all=27393 active=1517 piece=▁amanam
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=3600 all=27407 active=1531 piece=▁jiraadhu
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=3620 all=27441 active=1404 piece=eenyaa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=3640 all=27499 active=1462 piece=▁fokkisaa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=3660 all=27504 active=1467 piece=elaa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=3680 all=27554 active=1517 piece=▁dhabee
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=3700 all=27580 active=1543 piece=▁jedhamee
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=3720 all=27568 active=1367 piece=▁yeroodhaan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=3740 all=27611 active=1410 piece=▁email
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=3760 all=27664 active=1463 piece=▁beekuun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=3780 all=27659 active=1458 piece=▁barbaaddi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=3800 all=27670 active=1469 piece=▁siq
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=34 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=3820 all=27718 active=1421 piece=▁yaaltu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=3840 all=27712 active=1415 piece=▁addunyaan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=3860 all=27796 active=1499 piece=ktiri
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=3880 all=27836 active=1539 piece=▁dhabde
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=3900 all=27857 active=1560 piece=▁raawwate
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=33 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=3920 all=27864 active=1400 piece=ent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=3940 all=27953 active=1489 piece=▁barate
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=3960 all=27945 active=1481 piece=▁komachuu
# trainer_interface.cc(689) LOG(INFO) Saving model: om.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: om.vocab
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 207
#     203
#     204     return x
#     205 # Encoder
#     206 encoder_inputs = Input(shape=(max_in,))
# --> 207 enc_embed = Embedding(am_vocab_size, d_model)(encoder_inputs)
#     208 enc_embed += positional_encoding(max_in, d_model)
#     209
#     210 enc_output = encoder(enc_embed, num_layers=2)
#
# NameError: name 'am_vocab_size' is not defined

# %%
def translate(sentence):

    encoded = am_sp.encode(sentence, out_type=int)
    encoded = pad_sequences([encoded], maxlen=max_in, padding='post')

    output = [am_sp.bos_id()]  # IMPORTANT FIX

    for _ in range(max_out):

        dec_input = pad_sequences(
            [output],
            maxlen=max_out-1,
            padding='post'
        )

        preds = model.predict([encoded, dec_input], verbose=0)

        next_token = np.argmax(preds[0, len(output)-1])

        if next_token == om_sp.eos_id():
            break

        output.append(int(next_token))

    return om_sp.decode(output)

# %%
test_sentences = [
    "ሰላም",
    "እንዴት ነህ",
    "አመሰግናለሁ"
]

for sent in test_sentences:
    print("Amharic:", sent)
    print("Oromo :", translate(sent))
    print("-" * 50)
